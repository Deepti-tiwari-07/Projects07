# %%
import pandas as pd

# %%
df1 = pd.read_csv("/content/sample_data/AllItems (1).csv", skiprows=960,encoding = "latin-1")

# %%
df1.head()
# Out:
#    29/10/2021 15:14:35  \
# 0  25/11/2021 18:40:05
# 1  26/11/2021 15:46:09
# 2  13/10/2021 18:01:33
# 3  07/10/2022 13:43:29
# 4  25/11/2021 18:20:25
#
#   Enquiry from Srekanth Nilakantan on Daft.ie | House Share | 1A, Mountjoy Street, Dublin 1  \
# 0  Enquiry from janer hurtado  on Daft.ie | Studi...
# 1  Enquiry from Dillon Forde  on Daft.ie | Studio...
# 2  Enquiry from ChloÃÂ© Yannic on Daft.ie | Hous...
# 3  Enquiry from Juan Juzgado on Daft.ie | Apartme...
# 4  Enquiry from Amanda Zeila on Daft.ie | Studio ...
#
# ...

# %%
df1.columns = ["date","subject","body","from","to","cc","attach","arrmessage","a"]

# %%
d3=df1[['body']].copy()

# %%
d3.head()
# Out:
#                                                 body
# 0  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...
# 1  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...
# 2  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...
# 3  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...
# 4  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...

# %%
data= d3.body.str.split("Message:", expand = True)

# %%
data.head()
# Out:
#                                                    0  \
# 0  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...
# 1  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...
# 2  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...
# 3  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...
# 4  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...
#
#                                                    1
# 0   Hello, I am very interested in the studio. Co...
# 1   Hi my partner and I are planning on moving to...
# 2   Hello ! My name is ChloÃÂ©, I am 22 years ol...
# 3   Hi, my name is Juan Juzgado, I am from Spanis...
# 4   Hello, My name is Amanda and me and my boyfri...

# %%
data.columns = ["email", "message"]

# %%
f_data=data['message']

# %%
data= data.email.str.split("Email", expand = True)

# %%
data.head()
# Out:
#                                                    0  \
# 0  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...
# 1  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...
# 2  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...
# 3  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...
# 4  \r\n\r\n\r\nNew Enquiry\r\n\r\n\r\n\r\n\r\n\r\...
#
#                                                    1
# 0  : janertauro@gmail.com<mailto:janertauro@gmail...
# 1  : gracepaterson123@gmail.com<mailto:gracepater...
# 2  : chloe.yannic@gmail.com<mailto:chloe.yannic@g...
# 3  : juanjuzgadosoler@gmail.com<mailto:juanjuzgad...
# 4  : amandazeila17@gmail.com<mailto:amandazeila17...

# %%
data.columns = ["grab", "main"]

# %%
data= data.main.str.split("<", expand = True)

# %%
data.head()
# Out:
#                               0  \
# 0        : janertauro@gmail.com
# 1  : gracepaterson123@gmail.com
# 2      : chloe.yannic@gmail.com
# 3  : juanjuzgadosoler@gmail.com
# 4     : amandazeila17@gmail.com
#
#                                                    1  \
# 0  mailto:janertauro@gmail.com>\r\n\r\nPhone: 083...
# 1  mailto:gracepaterson123@gmail.com>\r\n\r\nPhon...
# 2  mailto:chloe.yannic@gmail.com>\r\n\r\nPhone: +...
# 3         mailto:juanjuzgadosoler@gmail.com>\r\n\r\n
# 4  mailto:amandazeila17@gmail.com>\r\n\r\nPhone: ...
#
#                            2     3     4     5     6     7
# 0    tel:0831129661>\r\n\r\n  None  None  None  None  None
# 1    tel:0838162058>\r\n\r\n  None  None  None  None  None
# 2  tel:+33622350454>\r\n\r\n  None  None  None  None  None
# 3                       None  None  None  None  None  None
# 4  tel:+40759518529>\r\n\r\n  None  None  None  None  None

# %%
data=data[0]

# %%
data.columns = ["mail"]

# %%
data.head()
# Out:
# 0          : janertauro@gmail.com
# 1    : gracepaterson123@gmail.com
# 2        : chloe.yannic@gmail.com
# 3    : juanjuzgadosoler@gmail.com
# 4       : amandazeila17@gmail.com
# Name: 0, dtype: object

# %%
data= data.str.split(":", expand = True)

# %%
data.head()
# Out:
#   0                            1     2     3     4     5     6     7
# 0           janertauro@gmail.com  None  None  None  None  None  None
# 1     gracepaterson123@gmail.com  None  None  None  None  None  None
# 2         chloe.yannic@gmail.com  None  None  None  None  None  None
# 3     juanjuzgadosoler@gmail.com  None  None  None  None  None  None
# 4        amandazeila17@gmail.com  None  None  None  None  None  None

# %%
data=data[1]

# %%
data
# Out:
# 0             janertauro@gmail.com
# 1       gracepaterson123@gmail.com
# 2           chloe.yannic@gmail.com
# 3       juanjuzgadosoler@gmail.com
# 4          amandazeila17@gmail.com
#                   ...
# 460               ononwa@yahoo.com
# 461             zoes1215@gmail.com
# 462          hayleymbell@gmail.com
# 463           riariseroy@gmail.com
# 464                           None
# Name: 1, Length: 465, dtype: object

# %%
whole_data= pd.concat([data,f_data],axis=1)

# %%
whole_data.columns = ["EmailID","Message"]

# %%
whole_data.head()
# Out:
#                        EmailID  \
# 0         janertauro@gmail.com
# 1   gracepaterson123@gmail.com
# 2       chloe.yannic@gmail.com
# 3   juanjuzgadosoler@gmail.com
# 4      amandazeila17@gmail.com
#
#                                              Message
# 0   Hello, I am very interested in the studio. Co...
# 1   Hi my partner and I are planning on moving to...
# 2   Hello ! My name is ChloÃÂ©, I am 22 years ol...
# 3   Hi, my name is Juan Juzgado, I am from Spanis...
# 4   Hello, My name is Amanda and me and my boyfri...

# %%
new_data=whole_data.groupby('EmailID')

# %%
new_data.head()
# Out:
#                          EmailID  \
# 0           janertauro@gmail.com
# 1     gracepaterson123@gmail.com
# 2         chloe.yannic@gmail.com
# 3     juanjuzgadosoler@gmail.com
# 4        amandazeila17@gmail.com
# ..                           ...
# 456         vecosta.ve@gmail.com
# 460             ononwa@yahoo.com
# 461           zoes1215@gmail.com
# 462        hayleymbell@gmail.com
# 463         riariseroy@gmail.com
#
#                                                Message
# 0     Hello, I am very interested in the studio. Co...
# 1     Hi my partner and I are planning on moving to...
# 2     Hello ! My name is ChloÃÂ©, I am 22 years ol...
# 3     Hi, my name is Juan Juzgado, I am from Spanis...
# 4     Hello, My name is Amanda and me and my boyfri...
# ..                                                 ...
# 456   Hi Is this room available?\r\n\r\n\r\n\r\n <h...
# 460   Hi, I'm a young working professional original...
# 461   HI I was wondering if this room I still avail...
# ...

# %%
enfuse_data=pd.DataFrame(new_data)

# %%
enfuse_data.head()
# Out:
#                              0  \
# 0           14jj1997@gmail.com
# 1       99patrickras@gmail.com
# 2   Ionut.apostol100@gmail.com
# 3      Julienjung.jj@gmail.com
# 4      Katataumadrid@gmail.com
#
#                                                    1
# 0                  EmailID                       ...
# 1                       EmailID  \
# 374   99patric...
# 2                           EmailID  \
# 101   Ionu...
# 3                        EmailID  \
# 188   Julienj...
# 4                        EmailID  \
# 213   Katatau...

# %%
enfuse_data.to_csv("Enfuse_data.csv",sep=',',index=False,encoding='utf-8')
